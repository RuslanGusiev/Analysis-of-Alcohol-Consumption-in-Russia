# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.biztory.com/about'

# %%
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <!-- start coded_template: id:24630759483 path:generated_layouts/24630759482.html --><!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Biztory Group" name="author"/>
# <meta content="Biztory can help you solve any analytical challenge, whether on a technical or business level. Learn more about our mission and team here." name="description"/>
# <meta content="HubSpot" name="generator"/>
# <title>About</title>
# <link href="https://www.biztory.com/hubfs/favicon.ico" rel="shortcut icon"/>
# <script src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js"></script>
# ...

# %%
rows = soup.find_all("div", class_="m-member__overlay p-5 p-md-15")

# %%
rows
# Out:
# [<div class="m-member__overlay p-5 p-md-15">
#  <strong>Timothy Vermeiren</strong>
#  <p class="mb-5">Analytics Consultant</p>
#  <ul class="c-socials__list">
#  <li>
#  <a href="https://www.linkedin.com/in/timothy-vermeiren-5ab1b343/" target="_blank" title="LinkedIn">
#  <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M22.225 0H1.77C.79 0 0 .774 0 1.729v20.542C0 23.227.792 24 1.77 24h20.452C23.2 24 24 23.227 24 22.271V1.729C24 .774 23.2 0 22.222 0h.003zM3.555 20.452H7.12V9H3.556v11.452zM5.338 7.433a2.062 2.062 0 01-2.063-2.065 2.064 2.064 0 112.063 2.065zm15.11 13.019h-3.554v-5.569c0-1.328-.026-3.037-1.852-3.037-1.852 0-2.136 1.445-2.136 2.939v5.667H9.35V9h3.415v1.561h.045c.477-.9 1.638-1.85 3.37-1.85 3.602 0 4.268 2.37 4.268 5.455v6.286h-.001z" fill-rule="evenodd"></path></svg>
#  </a>
#  </li>
#  <li>
#  <a href="https://twitter.com/timothyvermeire?lang=en" target="_blank" title="Twitter">
# ...

# %%
rows2 = soup.find_all("p", class_="mb-5")

# %%
rows2[:5]
# Out:
# [<p class="mb-5">Analytics Consultant</p>,
#  <p class="mb-5">Customer Success Manager</p>,
#  <p class="mb-5">Country Manager Belgium</p>,
#  <p class="mb-5">Managing Partner</p>,
#  <p class="mb-5">Operations Director</p>]

# %%
rows5 = []
for i in rows2:
    rows5.append(i.split("<p")[1])
rows5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-55c1f0f231fb> in <module>
#       1 rows5 = []
#       2 for i in rows2:
# ----> 3     rows5.append(i.split("<p")[1])
#       4 rows5
#
# TypeError: 'NoneType' object is not callable

# %%
rows3 = soup.find_all("strong")

# %%
rows4 = rows3[2:-7]
rows4
# Out:
# [<strong>Timothy Vermeiren</strong>,
#  <strong>Matthias Goossens</strong>,
#  <strong>Bjorn Cornelis</strong>,
#  <strong>Geoffrey Smolders</strong>,
#  <strong>Anna Bossmann</strong>,
#  <strong>Catalina Fluerici</strong>,
#  <strong>Wim Kegels</strong>,
#  <strong>Tim Dries</strong>,
#  <strong>Lex Pierik</strong>,
#  <strong>Hans-Kristiaan Koch</strong>,
#  <strong>Damien Arazi</strong>,
#  <strong>Alexander Philipeit</strong>,
#  <strong>Juan Manuel Perafan</strong>,
#  <strong>Nicolas Beunen</strong>,
#  <strong>Viktor Van Beersel</strong>,
#  <strong>Yun Yeung</strong>,
#  <strong>Kathryn McCrindle</strong>,
#  <strong>Joe Clarke</strong>,
#  <strong>Praveen Sam</strong>,
#  <strong>Jels de Maeght</strong>,
#  <strong>Frederik Gillis</strong>,
#  <strong>Connell Blackett</strong>,
#  <strong>James Smith</strong>,
#  <strong>Chris Dickson</strong>,
#  <strong>Daniel Caroli</strong>,
#  <strong>Ashleigh Trinh</strong>,
#  <strong>Merel Wallis de Vries</strong>,
# ...

# %%
rows6 = []
for i in rows4:
    rows6.append(i.split("<strong>")[1])
rows6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-691d939a464d> in <module>
#       1 rows6 = []
#       2 for i in rows4:
# ----> 3     rows6.append(i.split("<strong>"))
#       4 rows6
#
# TypeError: 'NoneType' object is not callable
