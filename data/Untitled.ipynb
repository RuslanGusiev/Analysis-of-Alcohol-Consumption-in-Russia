# %%
import pandas as pd

# %%
data = pd.read_excel('russian_population_new.xlsx')

# %%
data
# Out:
#                                    region  population
# 0                      Republic of Adygea      453376
# 1                              Altai Krai     2350080
# 2                             Amur Oblast      798424
# 3                      Arkhangelsk Oblast     1111031
# 4                        Astrakhan Oblast     1017514
# 5               Republic of Bashkortostan     4063293
# 6                         Belgorod Oblast     1549876
# 7                          Bryansk Oblast     1210982
# 8                    Republic of Buryatia      984511
# 9                         Vladimir Oblast     1378337
# 10                       Volgograd Oblast     2521276
# 11                         Vologda Oblast     1176689
# 12                        Voronezh Oblast     2333768
# 13                   Republic of Dagestan     3063885
# 14               Jewish Autonomous Oblast      162014
# 15                       Zabaykalsky Krai     1072806
# ...

# %%
data.to_csv('population.csv', index=False)
