# %%
import pandas as pd

# %%
data = pd.read_excel('russian_population_new.xlsx')

# %%
data
# Out:
#                                    region  population  distance to msk  \
# 0                      Republic of Adygea      453376           1669.0
# 1                              Altai Krai     2350080           3419.0
# 2                             Amur Oblast      798424           7985.0
# 3                      Arkhangelsk Oblast     1111031           1133.0
# 4                        Astrakhan Oblast     1017514           1534.0
# 5               Republic of Bashkortostan     4063293           1519.0
# 6                         Belgorod Oblast     1549876            695.0
# 7                          Bryansk Oblast     1210982            379.0
# 8                    Republic of Buryatia      984511           5532.0
# 9                         Vladimir Oblast     1378337            190.0
# 10                       Volgograd Oblast     2521276           1073.0
# 11                         Vologda Oblast     1176689            497.0
# ...

# %%
data.to_csv('population.csv', index=False)

# %%
data
# Out:
#                                    region  population  distance to msk  \
# 0                      Republic of Adygea      453376           1669.0
# 1                              Altai Krai     2350080           3419.0
# 2                             Amur Oblast      798424           7985.0
# 3                      Arkhangelsk Oblast     1111031           1133.0
# 4                        Astrakhan Oblast     1017514           1534.0
# 5               Republic of Bashkortostan     4063293           1519.0
# 6                         Belgorod Oblast     1549876            695.0
# 7                          Bryansk Oblast     1210982            379.0
# 8                    Republic of Buryatia      984511           5532.0
# 9                         Vladimir Oblast     1378337            190.0
# 10                       Volgograd Oblast     2521276           1073.0
# 11                         Vologda Oblast     1176689            497.0
# ...
